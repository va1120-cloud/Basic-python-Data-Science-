# %% [markdown]
# <a href="https://colab.research.google.com/github/va1120-cloud/Basic-python-Data-Science-/blob/main/untitlied.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
np.array([2,3,4])*2
# Out:
# array([4, 6, 8])
